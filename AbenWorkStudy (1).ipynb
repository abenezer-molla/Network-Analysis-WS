# %%
import pandas as pd #package for data analysis
import statsmodels.api as statsmodels #package for stats modelling
import seaborn as sns # nice plotting package
sns.set(color_codes=True, font_scale = 1.2)
sns.set_style("whitegrid")


# data loaded into pandas dataframe

data = pd.read_csv("MMG_sector_groups.csv")

print(data.shape) 
data
# Out:
# (214, 5)
#      mmg_purpose_sector                          mmg_purpose_sectorname  \
# 0                 11000                                       Education
# 1                 11100                                       Education
# 2                 11105                                       Education
# 3                 11110  Education policy and administrative management
# 4                 11120               Education facilities and training
# ..                  ...                                             ...
# 209               74010            Disaster prevention and preparedness
# 210               91010                            Administrative costs
# 211               93010                     Refugees in donor countries
# 212               99810                           Sectors not specified
# 213               99820              Promotion of development awareness
#
#      mmg_purpose_code                    mmg_purpose_codename  macro_sector
# ...

# %%
print(__doc__)

import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas

import argparse

import re

ap = argparse.ArgumentParser()
ap.add_argument("-p", "--file_path", default = 'WorkStudy/',
                help="path where all your csv files may be. \
                Please update the default with your common folder.")
ap.add_argument("-f", "--filename", default = 'MMG_sector_groups.csv')

args = vars(ap.parse_args())

x = pandas.read_csv('MMG_sector_groups.csv', usecols = ['macro_sector', 'mmg_purpose_code'])


booleans = []
for result in x.macro_sector:
    if re.search('Education', result):
        booleans.append(True)
    elif re.search('Health', result):
        booleans.append(True)       
    elif re.search('Wash', result):        
        booleans.append(True)        
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = x[Filtered]

NewData.shape

Rows_Removed = x.shape[0] - NewData.shape[0]

print("Rows Removed = ", str(Rows_Removed))
print(NewData)
# Out:
# Automatically created module for IPython interactive environment
# 214
# Rows Removed =  169
#     mmg_purpose_code macro_sector
# 0                110    Education
# 1                111    Education
# 2                111    Education
# 3                111    Education
# 4                111    Education
# 5                111    Education
# 6                112    Education
# 7                112    Education
# 8                112    Education
# 9                113    Education
# 10               113    Education
# 11               114    Education
# 12               114    Education
# 13               120       Health
# 14               121       Health
# 15               121       Health
# 16               121       Health
# 17               121       Health
# 18               121       Health
# 19               122       Health
# 20               122       Health
# 21               122       Health
# 22               122       Health
# 23               122       Health
# ...

# %%
print(__doc__)

import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas

import argparse

import re


x = pandas.read_csv('OECD_CRS_donors_classification_UTF8Aben.csv', usecols = ['DonorCode', 'DonorName', 'AgencyCode', 'IsWBG', 'IsPPD'])


x
# Out:
# Automatically created module for IPython interactive environment
#      DonorCode                       DonorName  AgencyCode  IsWBG  IsPPD
# 0            1                         Austria           1      0      0
# 1            1                         Austria           2      0      0
# 2            1                         Austria           3      0      0
# 3            1                         Austria           4      0      0
# 4            1                         Austria           5      0      0
# ..         ...                             ...         ...    ...    ...
# 719       1635    BBVA Microfinance Foundation           4      0      0
# 720       1636               Jacobs Foundation           1      0      0
# 721       1637                    Arcadia Fund           1      0      0
# 722       1638  Margaret A. Cargill Foundation           1      0      0
# 723       1639     La Caixa Banking Foundation           1      0      0
#
# [724 rows x 5 columns]

# %%
var1 = pd.read_table("CRS 2002-03 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])
    
var1['DonorCode']= var1['DonorCode'].apply(str)
var1['SectorCode']= var1['SectorCode'].apply(str)


booleans = []
for result in var1.DonorCode:
    if re.search('901', result):
        booleans.append(True)
    elif re.search('902', result):
        booleans.append(True)       
    elif re.search('903', result):        
        booleans.append(True)
    elif re.search('905', result):        
        booleans.append(True) 
    else:
        booleans.append(False)




Filtered = pd.Series(booleans)

NewData = var1[Filtered]

booleans1 = []

for result in NewData.SectorCode:

    if re.search('110', result):
        booleans1.append(True)
    elif re.search('111', result):
        booleans1.append(True) 
    elif re.search('112', result):
        booleans1.append(True)
    elif re.search('113', result):        
        booleans1.append(True)
    elif re.search('114', result):
        booleans1.append(True)
    elif re.search('115', result):
        booleans1.append(True)
    elif re.search('116', result):
        booleans1.append(True)
    elif re.search('117', result):
        booleans1.append(True)
    elif re.search('118', result):
        booleans1.append(True)
    elif re.search('119', result):
        booleans1.append(True)
    else:
        booleans1.append(False)

print(booleans1[0:100])
        
Filtered1 = pd.Series(booleans1)

NewData1 = NewData[Filtered1]

print(NewData1)
# Out:
# [False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]
# <ipython-input-30-050f975ac027>:58: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   NewData1 = NewData[Filtered1]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# ...

# %%
var1 = pd.read_table("CRS 2006 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])
    


var1['DonorCode']= var1['DonorCode'].apply(str)


booleans = []
for result in var1.DonorCode:
    if re.search('5', result):
        booleans.append(True)
    elif re.search('12', result):
        booleans.append(True)       
    elif re.search('701', result):        
        booleans.append(True)
    elif re.search('901', result):        
        booleans.append(True) 
    elif re.search('902', result):        
        booleans.append(True) 
    elif re.search('903', result):        
        booleans.append(True) 
    elif re.search('905', result):        
        booleans.append(True) 
    elif re.search('915', result):        
        booleans.append(True) 
    elif re.search('988', result):        
        booleans.append(True) 
    elif re.search('1312', result):        
        booleans.append(True) 
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = var1[Filtered]

NewData
# Out:
# 169071
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 39           5.0         0.00000           0.05272             0.000000
# 40           5.0         0.00000           0.01619             0.000000
# 41           5.0         0.00000           0.02837             0.000000
# 49           5.0         0.00000           0.03766             0.000000
# 101          5.0         0.12301           0.12301             0.133733
# ...          ...             ...               ...                  ...
# 168602       5.0         0.00490           0.00490             0.005327
# 168603       5.0         0.00000           0.00110             0.000000
# 168604       5.0         0.16712           0.16712             0.181688
# 168605       5.0         0.00879           0.00763             0.009556
# 168740       5.0         0.00000           0.95067             0.000000
#
#         USD_Disbursement_Defl  SectorCode
# 39                   0.057316       151.0
# ...

# %%
var2 = pd.read_table("CRS 2004-05 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])
    
 

var2['DonorCode']= var2['DonorCode'].apply(str)


booleans = []
for result in var2.DonorCode:
    if re.search('901', result):
        booleans.append(True)
    elif re.search('902', result):
        booleans.append(True)       
    elif re.search('903', result):        
        booleans.append(True)
    elif re.search('905', result):        
        booleans.append(True) 
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = var2[Filtered]

NewData
# Out:
# 303422
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 157        901.0             NaN          0.000000                  NaN
# 158        901.0             NaN          0.000000                  NaN
# 159        901.0             NaN          0.000000                  NaN
# 160        901.0             NaN          0.000000                  NaN
# 161        901.0             NaN          0.000000                  NaN
# ...          ...             ...               ...                  ...
# 302994     901.0            91.5          4.868896            102.21209
# 302995     901.0             0.0          0.000000              0.00000
# 302996     901.0             0.0          0.000000              0.00000
# 302997     901.0             NaN          0.761192                  NaN
# 302998     901.0             0.0          0.000000              0.00000
#
#         USD_Disbursement_Defl  SectorCode
# 157                  0.000000       113.0
# ...

# %%
var2 = pd.read_table("CRS 2006 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])
    

var3 

var2['DonorCode']= var2['DonorCode'].apply(str)


booleans = []
for result in var2.DonorCode:
    if re.search('5', result):
        booleans.append(True)
    elif re.search('12', result):
        booleans.append(True)       
    elif re.search('701', result):        
        booleans.append(True)
    elif re.search('901', result):        
        booleans.append(True) 
    elif re.search('902', result):        
        booleans.append(True) 
    elif re.search('903', result):        
        booleans.append(True) 
    elif re.search('905', result):        
        booleans.append(True) 
    elif re.search('915', result):        
        booleans.append(True) 
    elif re.search('988', result):        
        booleans.append(True) 
    elif re.search('1312', result):        
        booleans.append(True) 
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = var2[Filtered]

NewData
# Out:
# 169071
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 39           5.0         0.00000           0.05272             0.000000
# 40           5.0         0.00000           0.01619             0.000000
# 41           5.0         0.00000           0.02837             0.000000
# 49           5.0         0.00000           0.03766             0.000000
# 101          5.0         0.12301           0.12301             0.133733
# ...          ...             ...               ...                  ...
# 168602       5.0         0.00490           0.00490             0.005327
# 168603       5.0         0.00000           0.00110             0.000000
# 168604       5.0         0.16712           0.16712             0.181688
# 168605       5.0         0.00879           0.00763             0.009556
# 168740       5.0         0.00000           0.95067             0.000000
#
#         USD_Disbursement_Defl  SectorCode
# 39                   0.057316       151.0
# ...

# %%
var3 = pd.read_table("CRS 2006 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])
    

var3 

var3['DonorCode']= var3['DonorCode'].apply(str)
var3['SectorCode']= var3['SectorCode'].apply(str)

booleans1 = []
for result in var3.SectorCode:
    if re.search('110', result):
        booleans1.append(True)
    elif re.search('111', result):
        booleans1.append(True) 
    elif re.search('112', result):
        booleans1.append(True)
    elif re.search('113', result):        
        booleans1.append(True)
    elif re.search('114', result):
        booleans1.append(True)
    elif re.search('115', result):
        booleans1.append(True)
    elif re.search('116', result):
        booleans1.append(True)
    elif re.search('117', result):
        booleans1.append(True)
    elif re.search('118', result):
        booleans1.append(True)
    elif re.search('119', result):
        booleans1.append(True)
    else:
        booleans1.append(False)

print(len(booleans1))

Filtered = pd.Series(booleans1)

NewData = var3[Filtered]


NewData
# Out:
# 169071
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 42           1.0        0.271219          0.271219             0.303173
# 43           1.0        0.147935          0.147935             0.165364
# 48           1.0        3.139588          3.139588             3.509481
# 102          5.0       13.536470         13.536470            14.716435
# 104          2.0        0.021338          0.021338             0.023355
# ...          ...             ...               ...                  ...
# 168879       8.0        3.117790          0.638835             3.110125
# 168887      40.0        0.041571          0.041571             0.039491
# 168888     302.0        2.000000          0.588000             2.492936
# 168889      40.0        0.265094          0.265094             0.251826
# 169054     302.0       10.542000         10.542000            13.140268
#
#         USD_Disbursement_Defl SectorCode
# 42                   0.303173      114.0
# ...

# %%
var3 = pd.read_table("CRS 2006 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])
    

var3 

var3['DonorCode']= var3['DonorCode'].apply(str)


booleans = []
for result in var3.DonorCode:
    if re.search('5', result):
        booleans.append(True)
    elif re.search('12', result):
        booleans.append(True)       
    elif re.search('701', result):        
        booleans.append(True)
    elif re.search('901', result):        
        booleans.append(True) 
    elif re.search('902', result):        
        booleans.append(True) 
    elif re.search('903', result):        
        booleans.append(True) 
    elif re.search('905', result):        
        booleans.append(True) 
    elif re.search('915', result):        
        booleans.append(True) 
    elif re.search('988', result):        
        booleans.append(True) 
    elif re.search('1312', result):        
        booleans.append(True) 
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = var3[Filtered]

NewData
# Out:
# 169071
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 39           5.0         0.00000           0.05272             0.000000
# 40           5.0         0.00000           0.01619             0.000000
# 41           5.0         0.00000           0.02837             0.000000
# 49           5.0         0.00000           0.03766             0.000000
# 101          5.0         0.12301           0.12301             0.133733
# ...          ...             ...               ...                  ...
# 168602       5.0         0.00490           0.00490             0.005327
# 168603       5.0         0.00000           0.00110             0.000000
# 168604       5.0         0.16712           0.16712             0.181688
# 168605       5.0         0.00879           0.00763             0.009556
# 168740       5.0         0.00000           0.95067             0.000000
#
#         USD_Disbursement_Defl  SectorCode
# 39                   0.057316       151.0
# ...

# %%
is_Education =  (NewData['SectorCode']== '111.0') 

newData1 = NewData[is_Education]

newData1

column_sum1 = newData1['USD_Commitment_Defl'].sum()

column_sum1


is_Education =  (NewData['SectorCode']== '110.0') 

newData2 = NewData[is_Education]

newData2

column_sum2 = newData2['USD_Commitment_Defl'].sum()

column_sum2


is_Education =  (NewData['SectorCode']== '112.0') 

newData3 = NewData[is_Education]

newData3

column_sum3 = newData3['USD_Commitment_Defl'].sum()

column_sum3



is_Education =  (NewData['SectorCode']== '112.0') 

newData4 = NewData[is_Education]

newData4

column_sum4 = newData4['USD_Commitment_Defl'].sum()

column_sum4


is_Education =  (NewData['SectorCode']== '113.0') 

newData5 = NewData[is_Education]

newData5

column_sum5 = newData5['USD_Commitment_Defl'].sum()

column_sum5


is_Education =  (NewData['SectorCode']== '114.0') 

newData6 = NewData[is_Education]

newData6

column_sum6 = newData6['USD_Commitment_Defl'].sum()

column_sum6




Total_USD_Commitment_Defl = column_sum1 + column_sum2 + column_sum3 + column_sum4 + column_sum5 + column_sum6

Total_USD_Commitment_Defl
# Out:
# 0.0

# %%
is_Education =  (NewData['SectorCode']== '111.0') 

newData1 = NewData[is_Education]

newData1

column_sum1 = newData1['USD_Disbursement_Defl'].sum()

column_sum1


is_Education =  (NewData['SectorCode']== '110.0') 

newData2 = NewData[is_Education]

newData2

column_sum2 = newData2['USD_Disbursement_Defl'].sum()

column_sum2


is_Education =  (NewData['SectorCode']== '112.0') 

newData3 = NewData[is_Education]

newData3

column_sum3 = newData3['USD_Disbursement_Defl'].sum()

column_sum3



is_Education =  (NewData['SectorCode']== '112.0') 

newData4 = NewData[is_Education]

newData4

column_sum4 = newData4['USD_Disbursement_Defl'].sum()

column_sum4


is_Education =  (NewData['SectorCode']== '113.0') 

newData5 = NewData[is_Education]

newData5

column_sum5 = newData5['USD_Disbursement_Defl'].sum()

column_sum5


is_Education =  (NewData['SectorCode']== '118.0') 

newData6 = NewData[is_Education]

newData6

column_sum6 = newData6['USD_Disbursement_Defl'].sum()

column_sum6



USD_Disbursement_Defl = column_sum1 + column_sum2 + column_sum3 + column_sum4 + column_sum5 + column_sum6

USD_Disbursement_Defl
# Out:
# 0.0

# %%
is_Education =  (NewData['SectorCode']== '111.0') 

newData1 = NewData[is_Education]

newData1

column_sum1 = newData1['USD_Commitment'].sum()

column_sum1


is_Education =  (NewData['SectorCode']== '110.0') 

newData2 = NewData[is_Education]

newData2

column_sum2 = newData2['USD_Commitment'].sum()

column_sum2


is_Education =  (NewData['SectorCode']== '112.0') 

newData3 = NewData[is_Education]

newData3

column_sum3 = newData3['USD_Commitment'].sum()

column_sum3



is_Education =  (NewData['SectorCode']== '112.0') 

newData4 = NewData[is_Education]

newData4

column_sum4 = newData4['USD_Commitment'].sum()

column_sum4


is_Education =  (NewData['SectorCode']== '113.0') 

newData5 = NewData[is_Education]

newData5

column_sum5 = newData5['USD_Commitment'].sum()

column_sum5


is_Education =  (NewData['SectorCode']== '114.0') 

newData6 = NewData[is_Education]

newData6

column_sum6 = newData6['USD_Commitment'].sum()

column_sum6




USD_Commitment = column_sum1 + column_sum2 + column_sum3 + column_sum4 + column_sum5 + column_sum6

USD_Commitment
# Out:
# 0.0

# %%
is_Education =  (NewData['SectorCode']== '111.0') 

newData1 = NewData[is_Education]

newData1

column_sum1 = newData1['USD_Disbursement'].sum()

column_sum1


is_Education =  (NewData['SectorCode']== '110.0') 

newData2 = NewData[is_Education]

newData2

column_sum2 = newData2['USD_Disbursement'].sum()

column_sum2


is_Education =  (NewData['SectorCode']== '112.0') 

newData3 = NewData[is_Education]

newData3

column_sum3 = newData3['USD_Disbursement'].sum()

column_sum3



is_Education =  (NewData['SectorCode']== '112.0') 

newData4 = NewData[is_Education]

newData4

column_sum4 = newData4['USD_Disbursement'].sum()

column_sum4


is_Education =  (NewData['SectorCode']== '113.0') 

newData5 = NewData[is_Education]

newData5

column_sum5 = newData5['USD_Disbursement'].sum()

column_sum5


is_Education =  (NewData['SectorCode']== '114.0') 

newData6 = NewData[is_Education]

newData6

column_sum6 = newData6['USD_Disbursement'].sum()

column_sum6




USD_Disbursement = column_sum1 + column_sum2 + column_sum3 + column_sum4 + column_sum5 + column_sum6

USD_Disbursement
# Out:
# 0.0

# %%
import matplotlib.pyplot as plt

import numpy as np

x = ['USD_Commitment']

USD_Commitment_PPD  = 15274.936426

USD_Commitment_WBG  = 1000

USD_Disbursement_PPD  = 15274.936426

USD_Disbursement_WBG  = 0

plt.bar(x, USD_Commitment_PPD, 0.4, label = "PPD")

plt.bar(x, USD_Commitment_WBG, 0.4, bottom  = USD_Commitment_PPD , label = "WBG")



plt.show()
'''
USD_Commitment_Defl = 16144.084697000002

USD_Disbursement_Defl  =13756.036857000001


'''
# Out:
# '\nUSD_Commitment_Defl = 16144.084697000002\n\nUSD_Disbursement_Defl  =13756.036857000001\n\n\n'

# %%
var4 = pd.read_table("CRS 2007 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])
    

 

var4['DonorCode']= var4['DonorCode'].apply(str)


booleans = []
for result in var4.DonorCode:
    if re.search('901', result):
        booleans.append(True)
    elif re.search('902', result):
        booleans.append(True)       
    elif re.search('903', result):        
        booleans.append(True)
    elif re.search('905', result):        
        booleans.append(True) 
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = var4[Filtered]

NewData
# Out:
# 177584
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 835        901.0            2.60          0.043837             2.601973
# 836        901.0            9.62          0.162195             9.627299
# 851        905.0            0.00          0.978001             0.000000
# 852        901.0            0.00          0.000000             0.000000
# 853        901.0            0.00          0.000000             0.000000
# ...          ...             ...               ...                  ...
# 117295     905.0            0.00          0.000000             0.000000
# 117296     905.0            0.00          0.000000             0.000000
# 117297     905.0           19.80          0.000000            19.815023
# 117298     905.0            0.00          0.000000             0.000000
# 117299     905.0            0.00          3.794830             0.000000
#
#         USD_Disbursement_Defl  SectorCode
# 835                  0.043870       220.0
# ...

# %%
var4 = pd.read_table("CRS 2006 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])
    

var3 

var4['DonorCode']= var4['DonorCode'].apply(str)


booleans = []
for result in var4.DonorCode:
    if re.search('5', result):
        booleans.append(True)
    elif re.search('12', result):
        booleans.append(True)       
    elif re.search('701', result):        
        booleans.append(True)
    elif re.search('901', result):        
        booleans.append(True) 
    elif re.search('902', result):        
        booleans.append(True) 
    elif re.search('903', result):        
        booleans.append(True) 
    elif re.search('905', result):        
        booleans.append(True) 
    elif re.search('915', result):        
        booleans.append(True) 
    elif re.search('988', result):        
        booleans.append(True) 
    elif re.search('1312', result):        
        booleans.append(True) 
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = var4[Filtered]

NewData
# Out:
# 169071
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 39           5.0         0.00000           0.05272             0.000000
# 40           5.0         0.00000           0.01619             0.000000
# 41           5.0         0.00000           0.02837             0.000000
# 49           5.0         0.00000           0.03766             0.000000
# 101          5.0         0.12301           0.12301             0.133733
# ...          ...             ...               ...                  ...
# 168602       5.0         0.00490           0.00490             0.005327
# 168603       5.0         0.00000           0.00110             0.000000
# 168604       5.0         0.16712           0.16712             0.181688
# 168605       5.0         0.00879           0.00763             0.009556
# 168740       5.0         0.00000           0.95067             0.000000
#
#         USD_Disbursement_Defl  SectorCode
# 39                   0.057316       151.0
# ...

# %%
var5 = pd.read_table("CRS 2009 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])
    

var5 


var5['DonorCode']= var5['DonorCode'].apply(str)


booleans = []
for result in var5.DonorCode:
    if re.search('901', result):
        booleans.append(True)
    elif re.search('902', result):
        booleans.append(True)       
    elif re.search('903', result):        
        booleans.append(True)
    elif re.search('905', result):        
        booleans.append(True) 
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = var5[Filtered]

NewData
# Out:
# 238919
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 667        901.0             NaN         -0.009659                  NaN
# 668        901.0             NaN         -0.001009                  NaN
# 669        901.0             NaN         -0.001730                  NaN
# 680        901.0             0.0          0.000000                  0.0
# 684        901.0             0.0          0.000000                  0.0
# ...          ...             ...               ...                  ...
# 238672     901.0             NaN          0.000000                  NaN
# 238673     901.0             NaN          0.000000                  NaN
# 238674     901.0             NaN          0.000000                  NaN
# 238675     901.0             NaN          0.000000                  NaN
# 238682     901.0             0.0          0.007980                  0.0
#
#         USD_Disbursement_Defl  SectorCode
# 667                 -0.009548       112.0
# ...

# %%
var5 = pd.read_table("CRS 2006 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])
    



var5['DonorCode']= var5['DonorCode'].apply(str)


booleans = []
for result in var5.DonorCode:
    if re.search('5', result):
        booleans.append(True)
    elif re.search('12', result):
        booleans.append(True)       
    elif re.search('701', result):        
        booleans.append(True)
    elif re.search('901', result):        
        booleans.append(True) 
    elif re.search('902', result):        
        booleans.append(True) 
    elif re.search('903', result):        
        booleans.append(True) 
    elif re.search('905', result):        
        booleans.append(True) 
    elif re.search('915', result):        
        booleans.append(True) 
    elif re.search('988', result):        
        booleans.append(True) 
    elif re.search('1312', result):        
        booleans.append(True) 
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = var5[Filtered]

NewData
# Out:
# 169071
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 39           5.0         0.00000           0.05272             0.000000
# 40           5.0         0.00000           0.01619             0.000000
# 41           5.0         0.00000           0.02837             0.000000
# 49           5.0         0.00000           0.03766             0.000000
# 101          5.0         0.12301           0.12301             0.133733
# ...          ...             ...               ...                  ...
# 168602       5.0         0.00490           0.00490             0.005327
# 168603       5.0         0.00000           0.00110             0.000000
# 168604       5.0         0.16712           0.16712             0.181688
# 168605       5.0         0.00879           0.00763             0.009556
# 168740       5.0         0.00000           0.95067             0.000000
#
#         USD_Disbursement_Defl  SectorCode
# 39                   0.057316       151.0
# ...

# %%
var6 = pd.read_table("CRS 2010 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])
    

var6  


var6['DonorCode']= var6['DonorCode'].apply(str)


booleans = []
for result in var5.DonorCode:
    if re.search('901', result):
        booleans.append(True)
    elif re.search('902', result):
        booleans.append(True)       
    elif re.search('903', result):        
        booleans.append(True)
    elif re.search('905', result):        
        booleans.append(True) 
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = var6[Filtered]

NewData
# Out:
# 238919
# <ipython-input-67-5fdbbb89979d>:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   NewData = var6[Filtered]
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 667        905.0        0.000000          0.364968             0.000000
# 668        905.0        0.000000          2.876100             0.000000
# 669        901.0        0.000000          0.000000             0.000000
# 680        901.0        0.000000          0.000000             0.000000
# 684        701.0        0.014649          0.014471             0.011979
# ...          ...             ...               ...                  ...
# 232851     909.0             NaN          0.000000                  NaN
# 232852     909.0             NaN          0.035458                  NaN
# 232853     909.0             NaN          1.232537                  NaN
# 232854     909.0             NaN          0.041370                  NaN
# ...

# %%
var6 = pd.read_table("CRS 2006 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])
    



var6['DonorCode']= var6['DonorCode'].apply(str)


booleans = []
for result in var6.DonorCode:
    if re.search('5', result):
        booleans.append(True)
    elif re.search('12', result):
        booleans.append(True)       
    elif re.search('701', result):        
        booleans.append(True)
    elif re.search('901', result):        
        booleans.append(True) 
    elif re.search('902', result):        
        booleans.append(True) 
    elif re.search('903', result):        
        booleans.append(True) 
    elif re.search('905', result):        
        booleans.append(True) 
    elif re.search('915', result):        
        booleans.append(True) 
    elif re.search('988', result):        
        booleans.append(True) 
    elif re.search('1312', result):        
        booleans.append(True) 
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = var6[Filtered]

NewData
# Out:
# 169071
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 39           5.0         0.00000           0.05272             0.000000
# 40           5.0         0.00000           0.01619             0.000000
# 41           5.0         0.00000           0.02837             0.000000
# 49           5.0         0.00000           0.03766             0.000000
# 101          5.0         0.12301           0.12301             0.133733
# ...          ...             ...               ...                  ...
# 168602       5.0         0.00490           0.00490             0.005327
# 168603       5.0         0.00000           0.00110             0.000000
# 168604       5.0         0.16712           0.16712             0.181688
# 168605       5.0         0.00879           0.00763             0.009556
# 168740       5.0         0.00000           0.95067             0.000000
#
#         USD_Disbursement_Defl  SectorCode
# 39                   0.057316       151.0
# ...

# %%
var7 = pd.read_table("CRS 2011 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])
     


var7['DonorCode']= var7['DonorCode'].apply(str)


booleans = []
for result in var7.DonorCode:
    if re.search('901', result):
        booleans.append(True)
    elif re.search('902', result):
        booleans.append(True)       
    elif re.search('903', result):        
        booleans.append(True)
    elif re.search('905', result):        
        booleans.append(True) 
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = var7[Filtered]

NewData
# Out:
# 226015
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 978        905.0           0.000          0.440918             0.000000
# 979        905.0           0.000          0.058953             0.000000
# 980        905.0           0.000          0.000000             0.000000
# 981        905.0           0.000         -0.034577             0.000000
# 982        905.0           0.000         -0.036738             0.000000
# ...          ...             ...               ...                  ...
# 222825     905.0           0.000          0.000000             0.000000
# 225267     905.0           0.000          0.000000             0.000000
# 225306     905.0           5.983          0.000000             5.523477
# 225308     905.0          13.317          0.000000            12.294191
# 225333     905.0          45.126          0.000000            41.660108
#
#         USD_Disbursement_Defl  SectorCode
# 978                  0.407053       410.0
# ...

# %%
var7 = pd.read_table("CRS 2006 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])
    



var7['DonorCode']= var7['DonorCode'].apply(str)


booleans = []
for result in var7.DonorCode:
    if re.search('5', result):
        booleans.append(True)
    elif re.search('12', result):
        booleans.append(True)       
    elif re.search('701', result):        
        booleans.append(True)
    elif re.search('901', result):        
        booleans.append(True) 
    elif re.search('902', result):        
        booleans.append(True) 
    elif re.search('903', result):        
        booleans.append(True) 
    elif re.search('905', result):        
        booleans.append(True) 
    elif re.search('915', result):        
        booleans.append(True) 
    elif re.search('988', result):        
        booleans.append(True) 
    elif re.search('1312', result):        
        booleans.append(True) 
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = var7[Filtered]

NewData
# Out:
# 169071
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 39           5.0         0.00000           0.05272             0.000000
# 40           5.0         0.00000           0.01619             0.000000
# 41           5.0         0.00000           0.02837             0.000000
# 49           5.0         0.00000           0.03766             0.000000
# 101          5.0         0.12301           0.12301             0.133733
# ...          ...             ...               ...                  ...
# 168602       5.0         0.00490           0.00490             0.005327
# 168603       5.0         0.00000           0.00110             0.000000
# 168604       5.0         0.16712           0.16712             0.181688
# 168605       5.0         0.00879           0.00763             0.009556
# 168740       5.0         0.00000           0.95067             0.000000
#
#         USD_Disbursement_Defl  SectorCode
# 39                   0.057316       151.0
# ...

# %%
var8 = pd.read_table("CRS 2012 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])



var8['DonorCode']= var8['DonorCode'].apply(str)

booleans = []
for result in var8.DonorCode:
    if re.search('901', result):
        booleans.append(True)
    elif re.search('902', result):
        booleans.append(True)       
    elif re.search('903', result):        
        booleans.append(True)
    elif re.search('905', result):        
        booleans.append(True) 
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = var8[Filtered]

NewData
# Out:
# 225040
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 837        905.0             0.0          0.000000                  0.0
# 838        905.0             0.0         -0.005627                  0.0
# 839        905.0             0.0          0.000000                  0.0
# 1080       901.0             0.0          0.000000                  0.0
# 1081       901.0             0.0          0.000000                  0.0
# ...          ...             ...               ...                  ...
# 223203     905.0             0.0          0.000000                  0.0
# 223204     905.0             0.0          1.225980                  0.0
# 224701     901.0             0.0          0.000000                  0.0
# 224730     905.0             0.0          0.000000                  0.0
# 224731     905.0             0.0          0.000000                  0.0
#
#         USD_Disbursement_Defl  SectorCode
# 837                  0.000000       250.0
# ...

# %%
var8 = pd.read_table("CRS 2006 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])
    



var8['DonorCode']= var8['DonorCode'].apply(str)


booleans = []
for result in var8.DonorCode:
    if re.search('5', result):
        booleans.append(True)
    elif re.search('12', result):
        booleans.append(True)       
    elif re.search('701', result):        
        booleans.append(True)
    elif re.search('901', result):        
        booleans.append(True) 
    elif re.search('902', result):        
        booleans.append(True) 
    elif re.search('903', result):        
        booleans.append(True) 
    elif re.search('905', result):        
        booleans.append(True) 
    elif re.search('915', result):        
        booleans.append(True) 
    elif re.search('988', result):        
        booleans.append(True) 
    elif re.search('1312', result):        
        booleans.append(True) 
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = var8[Filtered]

NewData
# Out:
# 169071
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 39           5.0         0.00000           0.05272             0.000000
# 40           5.0         0.00000           0.01619             0.000000
# 41           5.0         0.00000           0.02837             0.000000
# 49           5.0         0.00000           0.03766             0.000000
# 101          5.0         0.12301           0.12301             0.133733
# ...          ...             ...               ...                  ...
# 168602       5.0         0.00490           0.00490             0.005327
# 168603       5.0         0.00000           0.00110             0.000000
# 168604       5.0         0.16712           0.16712             0.181688
# 168605       5.0         0.00879           0.00763             0.009556
# 168740       5.0         0.00000           0.95067             0.000000
#
#         USD_Disbursement_Defl  SectorCode
# 39                   0.057316       151.0
# ...

# %%
var9 = pd.read_table("CRS 2013 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])
 


var9['DonorCode']= var9['DonorCode'].apply(str)

booleans = []
for result in var9.DonorCode:
    if re.search('901', result):
        booleans.append(True)
    elif re.search('902', result):
        booleans.append(True)       
    elif re.search('903', result):        
        booleans.append(True)
    elif re.search('905', result):        
        booleans.append(True) 
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = var9[Filtered]


NewData
# Out:
# 229487
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 427        905.0             NaN               NaN                  NaN
# 430        905.0             NaN               NaN                  NaN
# 435        905.0             NaN               NaN                  NaN
# 436        901.0             NaN               NaN                  NaN
# 437        901.0             NaN               NaN                  NaN
# ...          ...             ...               ...                  ...
# 229331     905.0             NaN          2.553982                  NaN
# 229332     905.0             NaN          3.405310                  NaN
# 229333     901.0             NaN          0.070000                  NaN
# 229334     901.0             NaN          0.070000                  NaN
# 229335     901.0             NaN          0.110000                  NaN
#
#         USD_Disbursement_Defl  SectorCode
# 427                       NaN       151.0
# ...

# %%
var9 = pd.read_table("CRS 2006 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])
    



var9['DonorCode']= var9['DonorCode'].apply(str)


booleans = []
for result in var9.DonorCode:
    if re.search('5', result):
        booleans.append(True)
    elif re.search('12', result):
        booleans.append(True)       
    elif re.search('701', result):        
        booleans.append(True)
    elif re.search('901', result):        
        booleans.append(True) 
    elif re.search('902', result):        
        booleans.append(True) 
    elif re.search('903', result):        
        booleans.append(True) 
    elif re.search('905', result):        
        booleans.append(True) 
    elif re.search('915', result):        
        booleans.append(True) 
    elif re.search('988', result):        
        booleans.append(True) 
    elif re.search('1312', result):        
        booleans.append(True) 
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = var9[Filtered]

NewData
# Out:
# 169071
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 39           5.0         0.00000           0.05272             0.000000
# 40           5.0         0.00000           0.01619             0.000000
# 41           5.0         0.00000           0.02837             0.000000
# 49           5.0         0.00000           0.03766             0.000000
# 101          5.0         0.12301           0.12301             0.133733
# ...          ...             ...               ...                  ...
# 168602       5.0         0.00490           0.00490             0.005327
# 168603       5.0         0.00000           0.00110             0.000000
# 168604       5.0         0.16712           0.16712             0.181688
# 168605       5.0         0.00879           0.00763             0.009556
# 168740       5.0         0.00000           0.95067             0.000000
#
#         USD_Disbursement_Defl  SectorCode
# 39                   0.057316       151.0
# ...

# %%
var10 = pd.read_table("CRS 2019 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])

var10['DonorCode']= var10['DonorCode'].apply(str)

booleans = []
for result in var10.DonorCode:
    if re.search('901', result):
        booleans.append(True)
    elif re.search('902', result):
        booleans.append(True)       
    elif re.search('903', result):        
        booleans.append(True)
    elif re.search('905', result):        
        booleans.append(True) 
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = var10[Filtered]


NewData
# Out:
# 292717
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 116181     903.0      150.000000               NaN           150.000000
# 116182     903.0        0.129680               NaN             0.129680
# 116183     903.0        1.541779               NaN             1.541779
# 116184     903.0        9.064473               NaN             9.064473
# 116185     903.0        4.546822               NaN             4.546822
# ...          ...             ...               ...                  ...
# 291976     905.0        0.000000               0.0             0.000000
# 291977     905.0        0.000000               0.0             0.000000
# 291978     905.0        0.000000               0.0             0.000000
# 291979     905.0        0.000000               0.0             0.000000
# 291980     905.0        0.000000               0.0             0.000000
#
#         USD_Disbursement_Defl  SectorCode
# 116181                    NaN       322.0
# ...

# %%
var10 = pd.read_table("CRS 2006 data.txt", sep = "|", encoding='latin-1', usecols = ['SectorCode', 'DonorCode', 'USD_Commitment', 'USD_Disbursement', 'USD_Disbursement_Defl', 'USD_Commitment_Defl'])
    



var10['DonorCode']= var10['DonorCode'].apply(str)


booleans = []
for result in var10.DonorCode:
    if re.search('5', result):
        booleans.append(True)
    elif re.search('12', result):
        booleans.append(True)       
    elif re.search('701', result):        
        booleans.append(True)
    elif re.search('901', result):        
        booleans.append(True) 
    elif re.search('902', result):        
        booleans.append(True) 
    elif re.search('903', result):        
        booleans.append(True) 
    elif re.search('905', result):        
        booleans.append(True) 
    elif re.search('915', result):        
        booleans.append(True) 
    elif re.search('988', result):        
        booleans.append(True) 
    elif re.search('1312', result):        
        booleans.append(True) 
    else:
        booleans.append(False)

print(len(booleans))

Filtered = pd.Series(booleans)

NewData = var10[Filtered]

NewData
# Out:
# 169071
#        DonorCode  USD_Commitment  USD_Disbursement  USD_Commitment_Defl  \
# 39           5.0         0.00000           0.05272             0.000000
# 40           5.0         0.00000           0.01619             0.000000
# 41           5.0         0.00000           0.02837             0.000000
# 49           5.0         0.00000           0.03766             0.000000
# 101          5.0         0.12301           0.12301             0.133733
# ...          ...             ...               ...                  ...
# 168602       5.0         0.00490           0.00490             0.005327
# 168603       5.0         0.00000           0.00110             0.000000
# 168604       5.0         0.16712           0.16712             0.181688
# 168605       5.0         0.00879           0.00763             0.009556
# 168740       5.0         0.00000           0.95067             0.000000
#
#         USD_Disbursement_Defl  SectorCode
# 39                   0.057316       151.0
# ...
